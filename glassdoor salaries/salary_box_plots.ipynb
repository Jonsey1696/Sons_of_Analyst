# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import master df

jobs_df=pd.read_csv("Coordinates.csv")
jobs_df.drop(columns="Unnamed: 0")
# Out:
#                  Job Title           Location  \
# 0           data scientist       New York, NY
# 1           data scientist      Chantilly, VA
# 2           data scientist      Cambridge, MA
# 3           data scientist  Overland Park, KS
# 4           data scientist  San Francisco, CA
# ..                     ...                ...
# 882  senior data scientist   Fort Belvoir, VA
# 883  senior data scientist        Seattle, WA
# 884  senior data scientist             Remote
# 885  senior data scientist      Cambridge, MA
# 886  senior data scientist         McLean, VA
#
#                                     Industry                     Sector  \
# 0                    Advertising & Marketing          Business Services
# 1                     Research & Development          Business Services
# 2                  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 3            Healthcare Services & Hospitals                 Healthcare
# 4                        Government Agencies                 Government
# ..                                       ...                        ...
# 882  Enterprise Software & Network Solutions     Information Technology
# 883                Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 884                                  Lending                    Finance
# 885                Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 886                      Government Agencies                 Government
#
#      salary_average           City State        Lat         Lng
# 0             84500       New York    NY  40.712775  -74.005973
# 1             84500      Chantilly    VA  38.894279  -77.431099
# 2             84500      Cambridge    MA  42.373616  -71.109733
# 3             84500  Overland Park    KS  38.982228  -94.670792
# 4             84500  San Francisco    CA  37.774929 -122.419415
# ..              ...            ...   ...        ...         ...
# 882           91500   Fort Belvoir    VA  38.718872  -77.154268
# 883          109000        Seattle    WA  47.606209 -122.332071
# 884           80000         Remote   NaN  45.333248 -122.572887
# 885           80000      Cambridge    MA  42.373616  -71.109733
# 886           80000         McLean    VA  38.933868  -77.177260
#
# [887 rows x 9 columns]

# %%
#Create subset dfs

junior_df=jobs_df[jobs_df["Job Title"]=="junior data scientist"]
mid_level_df=jobs_df[jobs_df["Job Title"]=="data scientist"]
senior_df=jobs_df[jobs_df["Job Title"]=="senior data scientist"]

# %%
junior_salaries=junior_df["salary_average"].tolist()
#junior_salaries
mid_salaries=mid_level_df["salary_average"].tolist()
senior_salaries=senior_df["salary_average"].tolist()

# %%
import statistics as sts

# %%
senior_salaries.sort()
print(sts.mean(senior_salaries))
# Out:
# 97171.69811320755

# %%
senior_salaries
# Out:
# [0,
#  0,
#  41600,
#  41600,
#  41600,
#  41600,
#  41600,
#  41600,
#  41600,
#  56500,
#  56500,
#  56500,
#  56500,
#  56500,
#  56500,
#  56500,
#  56500,
#  57000,
#  57000,
#  57000,
#  57000,
#  57000,
#  57000,
#  57000,
#  57000,
#  57000,
#  68500,
#  69500,
#  69500,
#  69500,
#  69500,
#  75500,
#  75500,
#  75500,
#  75500,
#  80000,
#  80000,
#  80000,
#  84500,
#  84500,
#  84500,
#  84500,
#  84500,
#  84500,
#  84500,
#  89500,
#  89500,
#  91000,
#  91500,
#  92000,
#  94500,
#  94500,
#  94500,
#  96500,
#  96500,
#  97000,
#  99500,
#  99500,
#  99500,
#  99500,
#  99500,
#  99500,
#  99500,
#  100500,
#  109000,
#  110500,
#  111000,
#  111000,
#  111000,
#  119000,
#  119000,
#  119000,
#  119000,
#  124500,
#  124500,
#  124500,
#  124500,
#  124500,
#  124500,
#  124500,
#  126500,
#  126500,
#  126500,
#  127500,
#  127500,
#  127500,
#  127500,
#  130000,
#  130000,
#  130000,
#  130000,
#  130500,
#  130500,
#  130500,
#  130500,
#  145500,
#  145500,
#  145500,
#  184000,
#  184000,
#  184000,
#  184000,
#  184000,
#  184000,
#  184000,
#  184000]

# %%
salaries = [junior_salaries, mid_salaries, senior_salaries]
levels=["Junior", "Mid-Level", "Senior"]
green_marker = dict(markerfacecolor='g', marker='o')

fig1, ax1 = plt.subplots()
ax1.set_title("Average Salary by Role Level")
ax1.boxplot(salaries, flierprops=green_marker)
ax1.set_ylabel('Salary')
plt.xticks([1, 2, 3], levels)

plt.show()
plt.savefig("average_salary_whiskers.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
